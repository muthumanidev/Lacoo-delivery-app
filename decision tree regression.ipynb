# %% [markdown]
# <a href="https://colab.research.google.com/github/muthumanidev/Lacoo-delivery-app/blob/master/decision%20tree%20regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1883730611.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("decision_tree_regression_data.xlsx")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel("decision_tree_regression_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1883730611.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("decision_tree_regression_data.xlsx")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel("decision_tree_regression_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1883730611.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("decision_tree_regression_data.xlsx")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel("/content/sample_data/decision_tree_regression_data.xlsx")

# %%
print("Original Data:")
print(df)
# Out:
# Original Data:
#     YearsExperience  ProjectsCompleted  ClientSatisfaction  TeamSize  \
# 0              13.3                 11                 5.8         2
# 1               6.9                 15                 3.1        11
# 2               7.8                  5                 8.7        14
# 3               8.2                 11                 6.1        11
# 4              12.5                 18                 2.2        15
# 5               5.7                 15                10.0         8
# 6               7.5                 11                 2.2         2
# 7              12.3                 10                 9.7         9
# 8               2.7                  4                 3.9         2
# 9               7.8                 17                 8.3         7
# 10             13.4                  3                 9.8        13
# 11              3.4                  7                 3.1        13
# ...

# %%
df_encoded = pd.get_dummies(df, columns=["Department"], drop_first=True)
df_encoded
# Out:
#     YearsExperience  ProjectsCompleted  ClientSatisfaction  TeamSize  \
# 0              13.3                 11                 5.8         2
# 1               6.9                 15                 3.1        11
# 2               7.8                  5                 8.7        14
# 3               8.2                 11                 6.1        11
# 4              12.5                 18                 2.2        15
# 5               5.7                 15                10.0         8
# 6               7.5                 11                 2.2         2
# 7              12.3                 10                 9.7         9
# 8               2.7                  4                 3.9         2
# 9               7.8                 17                 8.3         7
# 10             13.4                  3                 9.8        13
# 11              3.4                  7                 3.1        13
# 12             10.2                  2                 9.9        12
# ...

# %%
X = df_encoded.drop("PerformanceScore", axis=1)
y = df_encoded["PerformanceScore"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model = DecisionTreeRegressor(max_depth=4, random_state=42)
model.fit(X_train, y_train)
model
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([63.56, 86.22, 97.36, 84.96, 86.22])

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 326.1478000000001

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# -1.5233052388239603

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print
# Out:
# Mean Squared Error: 326.15
# R² Score: -1.52
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=X.columns, filled=True, rounded=True)
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
import pickle

file_name="decision_tree_regression_data.xlsx"
pickle.dump(model, open(file_name, "wb"))

# %%
load=pickle.load(open("/content/sample_data/decision_tree_regression_data.xlsx", "rb"))
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipython-input-1139870376.py in <cell line: 0>()
# ----> 1 load=pickle.load(open("/content/sample_data/decision_tree_regression_data.xlsx", "rb"))
#
# UnpicklingError: A load persistent id instruction was encountered,
# but no persistent_load function was specified.
